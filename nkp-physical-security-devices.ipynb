# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-physical-security-devices/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Physical Security Devices``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Physical Security Devices](#topphysicalSecurityDevices)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topphysicalSecurityDevicesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topphysicalSecurityDevices"></a>
# ### [Physical Security Devices](#physicalSecurityDevices)
#
# - [1. Course Introduction](#physicalSecurityDevices1CourseIntroduction) <br/><br/>
# - [2. Motion Detection and Video Surveillance](#physicalSecurityDevices2MotionDetectionandVideoSurveillance) <br/><br/>
# - [3. Asset Tracking](#physicalSecurityDevices3AssetTracking) <br/><br/>
# - [4. Tamper Detection](#physicalSecurityDevices4TamperDetection) <br/><br/>
# - [5. Prevention](#physicalSecurityDevices5Prevention)

# %% [markdown]
# ### [Practice: Implementing Security Devices](#practicephysicalSecurityDevices)
#
# * [1. Exercise: Implement Physical Security Devices](#exercisephysicalSecurityDevices)

# %% [markdown]
# <a id="topphysicalSecurityDevicesTest"></a>
# ### ⚡ [Test](#physicalSecurityDevicesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="physicalSecurityDevices"></a>
# ***
# ### Physical Security Devices
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="physicalSecurityDevices1CourseIntroduction"></a>
# ***
# ######  1. Course Introduction
# ***

# %% [markdown]
# Cover physical security devices.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="physicalSecurityDevices2MotionDetectionandVideoSurveillance"></a>
# ***
# ######  2. Motion Detection and Video Surveillance
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recognize when to implement motion detection and video surveillance``

# %% [markdown]
# Now, in this presentation, we'll take a look at several of the components that you might find in a security control center or a monitoring station. And with respect to what is being monitored in this regard, we are more so talking about physical activity.

# %% [markdown]
# So not so much accessing a file or a folder in an unauthorized fashion or hacking in through a firewall. So rather that physical access, so are people quite literally to get into any given environment and/or out without being detected.

# %% [markdown]
# So generally, you do want to keep an eye on that sort of thing. And you can expect to find something like a CCTV, or closed circuit TV system, which provides active monitoring and surveillance, usually 24/7.

# %% [markdown]
# Now, there might also be an intrusion detection system of some kind, but again, not really a network intrusion detection system. It's not monitoring network packets. It is quite literally monitoring if people are able to break into an environment. And of course, there would also be alarm monitoring associated with that, if of course they are able to break in.

# %% [markdown]
# So the components with respect to closed circuit TV, of course, involves the camera itself. There may be various other recorders, including audio recorders, but there has to be something that records the actual activity. And the monitoring station is typically where you would see all of the actual screens, the monitors for each camera. And you might see them switching from one view to another, things along those lines.

# %% [markdown]
# But with respect to the usage and/or the modes, clearly this is implemented for surveillance, but might also be for assessment. In some cases there is a lot of activity that is expected and normal, of course. But you might be trying to assess something that appears to be abnormal.

# %% [markdown]
# It's a fairly effective deterrent, of course. And it might also be used for evidentiary archives. Just keeping that data so you can go back and view on any given date to see what happened, if it is discovered that something was compromised.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Cameras
# ***

# %% [markdown]
# Now, with respect to the cameras themselves, there are a few different types. Of course an outdoor camera is usually mounted to the side of a building or something along those lines, generally has a fixed position. Now, there can be a few different types, but again, it simply means that the camera is not mobile in any way, shape, or form.

# %% [markdown]
# A PTZ camera is short for pan, tilt and zoom. So even though it might be fixed, it can still rotate on a pivot, for example. And it can zoom in to get better resolution and things like that.

# %% [markdown]
# You might see dome cameras, little more on the inside of most environments. You might see them, for example, on the ceiling of a bank and any other type of secure environment. And really any kind of IP camera simply means that it is attached to a network. So the entire network of cameras can communicate and send their images to a central location.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Cameras - Terms
# ***

# %% [markdown]
# Some key terms with respect to the camera itself. You can expect to see a value such as FPS, or frames per second. And the more frames per second you can capture, the greater the detail and the more data you can expect to gather. But you generally want to see a value that's a happy medium. Because, again, if you are capturing too many frames, that's a lot of data. And if you're just trying to capture a standard physical intrusion, you generally don't need very high values of frames per second. Standard video, a regular video camera, I believe is around 30 frames per second. So you can usually get by with values lower than that.

# %% [markdown]
# Certainly the resolution if you need to capture facial images, for example. You would want very high resolution, particularly if it's far away.

# %% [markdown]
# The lighting level certainly needs to be considered. Because if you anticipate people trying to intrude at night, for example, then you clearly want the area that is being monitored to be well lit.

# %% [markdown]
# Compression, because clearly you are storing a lot of data. So you would want to see that compressed. And then typically there's some sort of digital video recorder, or DVR, that actually records what is happening.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Cameras - Motion Detection
# ***

# %% [markdown]
# Now when it comes to motion detection, the capability of a surveillance system capture any given event at the point motion is detected by that system, is clearly what we are referring to. But most of them use a software based monitoring algorithm to detect the motion. And there are certain degrees, if you will, with respect to what will trigger any given motion. And you might be familiar with something like a home system that is motion detecting, but has a threshold, for example, that you can configure. Because if you have pets, for example, the assumption is that they are going to move around throughout the house while you are gone. And if it was set off by any kind of motion, clearly you'd be getting alarms all the time. So most of them are configurable with respect to what is the threshold of maybe the size of the object, or how much it moves.

# %% [markdown]
# But ultimately, it is really the idea of starting the capture process only when motion is detected. Because we don't really need to capture anything when there is nothing going on. Now this might also be referred to as activity detection, because, of course, motion is an activity.

# %% [markdown]
# But coming back to the more advanced motion detection surveillance systems that I referred to earlier, how some of them can be configured with thresholds. You might have this ability to implement a configuration that says, well, it's going to actually try to determine whether or not to initiate an alarm, based on the activity.

# %% [markdown]
# And again, I mentioned the home system that can be configured for sort of a size threshold, if we're talking about pets. Now the pets aren't very large. In most cases it's a dog or a cat.

# %% [markdown]
# So you might be able to configure some kind of threshold with respect to the size of the object that is being monitored. But if it's a person, well, that's significantly larger. So it can make that determination, as to whether or not this is actually suspicious movement.

# %% [markdown]
# Now there is also video content and analysis and even motion path analysis that can also be implemented. And this is detection based on the pixel change and/or video content analysis or even motion path analysis. And again, the idea here is that you typically want the system to be up and running 24/7 all the time. But if it alarmed every single time it captured any kind of motion, it would just keep going all the time in a lot of environments. So again, you can configure certain values to say that this is normal. Whenever it, quote, sees this kind of activity, then that can be considered normal.

# %% [markdown]
# Perhaps in a bank environment, if somebody always goes into the vault using the sort of the same path and the same general motions, and maybe even at the same time of day, those things can be considered. And you can, in essence, say that this is normal, this is acceptable. Do not fire off an alarm in that event. But that's up to you. How you configure the system is certainly your call. But it is generally something to be considered. But in most cases, you would probably error on the side of caution. If it's not sure, then let's alarm just to be safe.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="physicalSecurityDevices3AssetTracking"></a>
# ***
# ######  3. Asset Tracking
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``identify when to implement asset tracking``

# %% [markdown]
# In this presentation, we'll take a look at managing and maintaining asset inventory records.

# %% [markdown]
# And with respect [Asset Inventory Records. ] to what is generally recorded as part of any given organization's assets, it's usually more so hardware and software. As they're considered to be a little more crucial to being able to successfully implement security and risk management strategies.

# %% [markdown]
# But there may be other things that are included as well, but that is certainly going to vary depending on the organization.

# %% [markdown]
# So when it comes to marking or indicating any given asset, it should include the following, some sort of unique asset identifier which is typically a tag of some kind. So that of course it is uniquely identified amongst every asset. You should never have duplicate identifiers in any situation.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then it should also include some sort of qualitative and/or quantitative value, and that of course can include monetary value. How critical it is to the environment. And/or whether or not it is considered to be a high value asset.

# %% [markdown]
# It should also include components such as the location, where it is geographically, whether it's part of call it a headquarters or a remote site or a branch office.

# %% [markdown]
# And again, the security classification or the sensitivity level. That kind of relates to its value, of course. But it certainly is also something that should be recorded. In essence, how severe is it if this particular asset was lost or compromised.

# %% [markdown]
# It should also include an asset group if applicable. There might be certain assets of course that are part of a category, for example, all desktop computers, all laptop computers, all mobile devices, things along those lines.

# %% [markdown]
# It should indicate who is the owner and/or the custodian of the asset and the recovery priority. So if it is damaged, lost or stolen, you know, how quickly it should be replaced, what kind of severity level does its loss represent, things along those lines.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Software Asset Management
# ***

# %% [markdown]
# [Software Asset Management. ] And then when it comes to software asset management, this is of course used to identify and track an organization's operating systems.

# %% [markdown]
# The software applications that are in use.

# %% [markdown]
# The mobile device operating systems and the apps that are installed.

# %% [markdown]
# Any cloud applications that are being used, and possibly any virtualization that is being implemented.

# %% [markdown]
# And with respect to the inventory, keeping this up to date can be manual or automated, it depends on the system and your approach. But it should be cross-platform, because if you do have multiple different operating systems and different vendors. It should be able to operate and/or be accessible from just about any operating system, so something that is maybe web-based might be ideal. But, again, this is going to vary.

# %% [markdown]
# And licensing should also be considered, and you typically have an inventory of licenses as well. So when you purchase software for example, it defines that you can install it x number of times. So you can maintain an inventory of how many of those installations have occurred and or how many licences you have left.

# %% [markdown]
# It should also include audit information with respect to how often this is reviewed.

# %% [markdown]
# And perhaps maybe the history of the application, the versions that have been implemented.

# %% [markdown]
# Any overages with respect to tracking that usage. Again, you may have exceeded the installations in some cases. Something that indicates if there was any piracy that took place with respect to the software.

# %% [markdown]
# And if any virtualization is being implemented, in some cases, there are unique licensing conditions that apply to virtualization. Some examples include the fact that if you are running it virtually then there might only be a single copy running on a system that is accessed, perhaps using something like remote desktop. And as such, you only actually install it once, but it is still being used by multiple different users. So situations like that might have unique conditions in the licensing agreement.

# %% [markdown]
# And of course, the mobile devices as well. They certainly have software on them as well, so that should also be part of the overall process.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Hardware Asset Management
# ***

# %% [markdown]
# [Hardware Asset Management. ] And then finally, coming back to some hardware asset management.

# %% [markdown]
# This, of course, is centered around the physical components. In any given IT ecosystem, but it's not just the computers in most cases so things that you would also see would include the mobile devices, certainly the desktop computers, the laptops, and the servers.

# %% [markdown]
# But also routers, switches, firewalls, intrusion detection, cameras, anything that might fall under the category of security, they would probably be considered to be fairly critical.

# %% [markdown]
# And any other hardware that is deemed necessary by an organization to manage, disk storage arrays, backup devices, ultimately anything the environment feels should be tracked.

# %% [markdown]
# So there can certainly be a wide degree of variance with respect to what kind of hardware is really considered to be an important asset. Versus certain hardware that might not be as important.

# %% [markdown]
# So ultimately, whatever is being tracked in any kind of inventory system is again, going to vary depending on the environment. But if you do find yourself working in an environment that does maintain this, then it is a fairly critical component. These types of things would often be included in quarterly reports or annual reports to the stakeholders, things along those lines. The value of the physical assets is obviously something that helps to determine the bottom line of that business. So, it's certainly something that needs to be maintained and kept on top of to ensure that everything is current.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="physicalSecurityDevices4TamperDetection"></a>
# ***
# ######  4. Tamper Detection
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``describe the purpose of tamper detection``

# %% [markdown]
# [Topic title: Tamper Detection. The presenter is Aaron Sampson. ] Now every type of surveillance system of course has some kind of weakness. So in this presentation, we'll take a look at things such as tamper detection and how you might encounter cameras being tampered with so that they in essence are unable to record the activity. But tamper detection itself [Tamper Detection. ] is a setting on many different surveillance systems that alerts you if a camera is tampered with. So in other words, it reports back if the device itself has been altered and alerts are sent once an action is detected that its ability to record has been impacted. You can typically then log into the video management system to investigate what is affecting that system. Now of course it's not always sabotage, it could simply be a failure, but in either case it tells you this is what occurred, and as such, the device is no longer capable of recording or it's been at least diminished.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Blockage
# ***

# %% [markdown]
# [Blockage. ] So some of the actions in terms of defeating video cameras include blockage or blind detection and of course, if this is an attempt to intrude, it is usually intentional. So something as simple as a bag can be placed over the camera, a hand in front of it or just even a baseball hat. Those are clearly means to disrupt the surveillance, but of course you would have to have physical access to the camera itself. So again, depending on where it's mounted. Oftentimes they are out of reach or behind a cage, so that might not be as easy. But there are still a lot of different ways to block it or blind it. Now, some of them of course are unintentional. Maybe it's a fallen tree or a branch, or really any kind of object that is just blowing around in the wind. Such as a grocery bag that has simply snagged on the camera itself.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Redirecting
# ***

# %% [markdown]
# [Redirecting. ] Redirecting is quite literally pointing it in a different direction so you reposition it away from whatever mischievous activity you are trying to do. Again, that would require some kind of physical access to the camera so it's not always an option. And again, if it was behind that cage or something along those lines, maybe you might not even be able to do it. But if you can gain access, in a lot of cases it might not be too difficult to just point it somewhere else.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Defocusing
# ***

# %% [markdown]
# [Defocusing. ] Defocusing is any kind of an act that would [security camera. ] cause the camera to go out of focus, such as placing a lens like a magnifying glass in front of the actual camera lens. Or shining any kind of beam straight into it like a laser pointer, for example, would certainly throw it out of focus.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Spray-painting
# ***

# %% [markdown]
# [Spray-painting. ] Spray-painting, certainly an option if they aren't entirely accessible, this is deliberately covering the camera. So it cannot see anything, you cannot view the actual activity. So this common in mischief such as graffiti or hate crimes. But this would be an easy option, even if the camera was in, let's say, a wire mesh cage, it would not take much to spray paint through that to cover the lens. So, the overall idea's that cameras, while certainly useful, are not anywhere near 100% effective with respect to what they provide in terms of security. They can be somewhat easily circumvented.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="physicalSecurityDevices5Prevention"></a>
# ***
# ######  5. Prevention
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``summarize the purpose of prevention techniques such as badges, biometrics, smart cards, key fobs, and locks``

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Social Engineering
# ***

# %% [markdown]
# Now in this presentation, we'll take a look at several different implementations of security devices and or general approaches to security. We're going to begin with what's called social engineering. The social engineering is simply when a threat actor is able to get around whatever security barriers you put in place by getting flesh and blood people to do the work for them. If you've ever watched a heist movie, you know that a con-man is need to convince people to let down their guard. Unfortunately, there's a thousand ways to do this. So it's not like blocking a port on a Firewall. We have to educate our users on how to recognize valid people who are allowed to work on the network equipment. How to respond to phone calls, emails and texts that might seem to becoming from someone with authority. And what to do if they find a USB drive just lying around. We want to mention this first because every form of security can be undone [Social Engineering includes attacks based on human interaction that can circumvent nearly all other protections. Or when an untrusted (from a corporate perspective) individual convinces others to reveal information or perform actions such as tricking someone into helping them on the network, leaving an unattended USB flash drive with a payload or phishing communications.] if users in the inside allow circumvention of security devices, protocols and policies.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Control types
# ***

# %% [markdown]
# Now, let's look at control types. Control types don't refer to any specific device or even any specific method, rather, just the consideration with respect to how everything is managed.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Administrative
# ***

# %% [markdown]
# So, the Administrative refers to written documentation, so, policies and procedures, so people are aware of how security is implemented.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Technical
# ***

# %% [markdown]
# Technical control types do refer to general types of devices but not any specific ones. So in terms of categories, something that is digital might refer to a fire wall or an intrusion detection system or IDS. And something that is physical might refer to a door lock. Now, you might not think of that as technical per se but these days, a lot of door locks work on something like a smart card for example, to unlock it. So it's certainly a technical lock in that regard.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Operational
# ***

# %% [markdown]
# And then operational, is simply anything that ensures smooth and efficient day-to-day operations including things like recovery procedures. If something does happens and you have to revert back to older data for example. Or even recovery of physical assets, so just outlining how things are supposed to be under normal circumstances.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Devices - Badge
# ***

# %% [markdown]
# So then, with respect to some actual devices or approaches you might encounter, some kind of badge is quite common. When you do have physical security and this can provide access to buildings, parking lots, even the computer systems. Maybe more so, something like a server room for example. But these can not only allow access but they record the information, such as the name and access time. So when you're issued a badge, it has something that identifies you and records when you are given this access. So again, if it's something that is out of the ordinary, such as you work nine to five Monday through Friday but all of a sudden you're trying to access something at midnight on Saturday, then that's a little bit unusual.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Devices - Biometrics
# ***

# %% [markdown]
# Biometrics, include devices such as fingerprint readers, retina patterns and facial recognition but at some kind of physical characteristic of your body that's used to identify who you are. Now these are very commonly used in multifactor authentication. In other words it's used in conjunction with something else, it's not as common to see them as the only means of identification because again, there are ways to circumvent them but certainly very common when it's to supply a username and a password and then swipe your finger print. So that's dual or multi factor authentication.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Devices - Smart Cards
# ***

# %% [markdown]
# Smart cards certainly allow physical access to any kind of control device. Again, something like an electronic card or any implementation of dual-factor authentication is where you might see a smart card. So it's also known as integrated circuit cards or ICCs. And in some cases, they can be contact or contactless. There might be reader for example, that's able to pick up on the card without actually touching it. But it has to be fairly close. But again, this is not really all that different from a badge. But in many cases, you do find these things on things like credit cards or banking cards for example. The everyday approach of just tapping your card to make a payment, this is the contactless, in most cases. Most of the time we do actually touch it. But they can usually pick them up from a short distance.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Devices - Keypads
# ***

# %% [markdown]
# Keypads. Keypads are very common when it comes to door locks. It requires you to enter a PIN to gain access through the door. They tend to be a little less secure and are more susceptible to social engineering attacks. Somebody's just saying, I'm supposed to be able to get into this door, can you let me in? And then they just kind of shoulder surf you, as they enter the pin, so they're not particularly secure. And if it's the same code that everyone uses, then you tend to see the numbers on the key pin, actually start to visibly wear. That doesn't reveal the sequence but if it's a four number PIN for example and you notice the keys 1, 2, 3 and 4, just to keep it simple are more worn than others, well then you know it's a combination of those four characters. Plus they tend to leave fingerprints that get a little smudged, things along those lines. So, they aren't really considered to be particularly secure but it is another layer.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Devices - Key Fobs
# ***

# %% [markdown]
# Key fobs and proximity readers. These again can be used to manage door security. The key fob contains your identity information, they typically have to be in pretty close proximity. You might even have to swipe it for example depending on what physical style it is but another example just in home environments, there are door locks now that you can just touch as long as you have a fob on you it picks up on the fob and that's what unlocks the door. And this has the advantage of recording who access the lock and when it happened, so similar to badges or even smart cards.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Devices - Locks
# ***

# %% [markdown]
# Plain old locks. Preventative control measures used to keep resources secure. A padlock, an electronic lock, a laptop lock, just about any type of lock could be implemented in just about any situation.

# %% [markdown]
# Padlocks of course use keys, which aren't particularly secure anyway. You could lose the keys, someone could duplicate it, spread it around. So, electronic locks are becoming more common. But again, keypads, as just discussed, aren't the most secure approach either and a laptop lock is usually something that can be used to physically tether the laptop to something like a desk, so they would have to carry the whole desk out in order to get to the laptop. Usually those are combination locks but they might have a small padlock on them as well.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Conclusion - Physical Security should not be Overlooked
# ***

# %% [markdown]
# Ultimately, physical security is something that should not be overlooked in any given environment. It's often far too easy to gain physical access to any given environment. And in a lot of cases, once you're physically present, then intrusion becomes a lot simpler. So depending on the nature of your organization, the implementation of this type of security is certainly going to vary but it's something that is becoming more common in today's organizations.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="practicephysicalSecurityDevices"></a>
# ***
# ### Practice: Implementing Security Devices
# ***

# %% [markdown]
# After completing this topic, you should be able to: ``recognize when to implement physical security devices``

# %% [markdown]
# i. Describe motion detection.
#
#
# ii. Then to describe the various types of surveillance camera tampering.
#
#
# iii. Then to describe when to implement asset tracking.
#
#
# iv. And finally to describe the different types of biometrics authentication.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="exercisephysicalSecurityDevices"></a>
# ***
# ###### 1. Exercise: Implement Physical Security Devices
# ***

# %% [markdown]
# i. First task was to describe motion detection.

# %% [markdown]
# And this refers to the capability of a surveillance system to capture events at the point motion is detected by the system. In other words, it doesn't really record anything until something is detected. And this is certainly useful because if there's nothing happening, then you are recording, in essence, nothing. And this would take up an awful lot of space in terms of storage. So once the motion is detected, that can trigger the camera to start recording and you capture that activity.

# %% [markdown]
# ii. Then we asked to describe the various types of surveillance camera tampering.

# %% [markdown]
# And these can include, blockage, redirecting, defocusing, and spray-painting. And really spray-painting is, of course, a type of blockage but some blockage, of course, can also be unintentional. Such as a fallen tree branch or something that has simply blown over top of the camera.

# %% [markdown]
# iii. Then we asked to describe when to implement asset tracking and this is something that you would do when you need to implement a successful security and risk management strategy.

# %% [markdown]
# In other words, you quite simply need to know what you have in terms of being able to discover whether or not something is missing. So this of course gives you that baseline, if you will. Something to always compare to so that we can see this is what we had, and this is what we have now. So what has changed? And of course, in some cases, things are just removed because they were outdated or they simply became unnecessary or too old. Things along those lines, but if something was stolen, then clearly you would see it as missing from the inventory.

# %% [markdown]
# iv. And finally, we ask you to describe the different types of biometrics authentication.

# %% [markdown]
# And this might include fingerprint readers, retina scanners, and facial recognition. And I should mention that's becoming fairly common these days in laptops with webcams, you can implement that to log on. But typically when it comes to biometrics, it is generally not the only thing used for authentication because there are ways to circumvent this. For example, you can physically force someone to swipe their finger over the reader. Things along those lines, but it is common with multi factor authentication. So the user name and/or the password is required along with the fingerprint or the retina scan or the facial recognition. But that of course is up to you and the more components you implement in terms of authentication, certainly the safer it would be.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="physicalSecurityDevicesTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# &#x1F6A7;

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
